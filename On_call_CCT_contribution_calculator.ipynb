# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import datetime

# %%
df = pd.read_csv('James_Ruffle_All_Shift Data.csv')
df = df.loc[df['Location']=='NHNN'] #remove contrast cover shifts as these are not training relevant
df = df[~((df['Day'].isin(['Monday','Tuesday','Wednesday', 'Thursday', 'Friday'])) & (df['StartTime'] == '09:00') & (df['EndTime'] == '17:00'))] #takes on call shifts only
df.reset_index(drop=True, inplace=True)
print('rows of on call:',df.shape[0])
df
# Out:
# rows of on call: 180
#            Date        Day StartTime EndTime  Break          Name Grade  \
# 0    09/10/2021   Saturday     09:00   21:00      0  James Ruffle   SPR
# 1    10/10/2021     Sunday     09:00   21:00      0  James Ruffle   SPR
# 2    20/10/2021  Wednesday     17:00   21:00      0  James Ruffle   SPR
# 3    22/10/2021     Friday     21:00   09:00      0  James Ruffle   SPR
# 4    23/10/2021   Saturday     21:00   09:00      0  James Ruffle   SPR
# ..          ...        ...       ...     ...    ...           ...   ...
# 175  25/02/2025    Tuesday     17:00   21:00      0  James Ruffle   SPR
# 176  06/03/2025   Thursday     17:00   21:00      0  James Ruffle   SPR
# 177  08/03/2025   Saturday     09:00   21:00      0  James Ruffle   SPR
# 178  09/03/2025     Sunday     09:00   21:00      0  James Ruffle   SPR
# 179  21/03/2025     Friday     17:00   21:00      0  James Ruffle   SPR
#
#     TimesheetNo  NoOfHours  ShiftOurRef          Hospital/Arm Unit/Locality  \
# 0      W8439198       12.0     38200796  Specialist Hospitals  Queen Square
# 1      W8439198       12.0     38200797  Specialist Hospitals  Queen Square
# 2      W8506359        4.0     38361771  Specialist Hospitals  Queen Square
# 3      W8506359       12.0     38361902  Specialist Hospitals  Queen Square
# 4      W8506359       12.0     38361903  Specialist Hospitals  Queen Square
# ..          ...        ...          ...                   ...           ...
# 175   W14577246        4.0     53996029  Specialist Hospitals  Queen Square
# 176   W14609238        4.0     53961645  Specialist Hospitals  Queen Square
# 177   W14609238       12.0     53961739  Specialist Hospitals  Queen Square
# 178   W14609238       12.0     53961741  Specialist Hospitals  Queen Square
# 179   W14714465        4.0     54424747  Specialist Hospitals  Queen Square
#
#                      ShiftType Location
# 0                          NaN     NHNN
# 1                          NaN     NHNN
# 2                          NaN     NHNN
# 3    Nights (Banks & PCH Only)     NHNN
# 4    Nights (Banks & PCH Only)     NHNN
# ..                         ...      ...
# 175                        NaN     NHNN
# 176                        NaN     NHNN
# 177                        NaN     NHNN
# 178                        NaN     NHNN
# 179  Nights (Banks & PCH Only)     NHNN
#
# [180 rows x 14 columns]

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')

min_date = df['Date'].min()
max_date = df['Date'].max()

number_of_weeks = (max_date - min_date).days / 7
contract_hours = 44
total_hours = df['NoOfHours'].sum()

proportion = total_hours / (number_of_weeks * contract_hours)

print('Additional percentage FTE worked for on calls:', proportion * 100)
# Out:
# Additional percentage FTE worked for on calls: 14.409668568127664
